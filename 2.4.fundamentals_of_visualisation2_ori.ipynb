# %% [markdown]
# ### 2.4 Fundamentals of Visualisation - Seaborn

# %%
# Import Libraries

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from datetime import datetime as dt
import seaborn as sns

# %%
# Import Data

df = pd.read_csv('nycbike_data2.csv', index_col = 0)
# Out:
# /var/folders/8k/dxgtncgd49g2ryx410bsc12r0000gn/T/ipykernel_76103/3817353878.py:3: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('nycbike_data2.csv', index_col = 0)

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  F2147CAB2E003A12   classic_bike  2022-01-01 00:56:36  2022-01-01 01:06:55
# 1  27FF7FCE0F8A02DF   classic_bike  2022-01-01 15:42:26  2022-01-01 16:02:59
# 2  E413BC1D0B4C6031   classic_bike  2022-01-01 15:37:55  2022-01-01 16:03:05
# 3  1967ADD90811CE78  electric_bike  2022-01-01 17:35:23  2022-01-01 17:46:05
# 4  D199C729356BA836   classic_bike  2022-01-01 19:25:20  2022-01-01 19:41:53
#
#          start_station_name start_station_id               end_station_name  \
# 0  Cedar St & Evergreen Ave          4721.01  Willoughby Ave & Tompkins Ave
# 1  Albany St & Greenwich St          5145.02          Bayard St & Baxter St
# 2  Albany St & Greenwich St          5145.02          Bayard St & Baxter St
# 3   Cabrini Blvd & W 177 St           8358.1            Broadway & W 220 St
# 4           5 Ave & E 72 St          7100.07                W 41 St & 8 Ave
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual  \
# 0        4665.02  40.696710 -73.928070  40.694254 -73.946269        member
# 1        5351.03  40.709267 -74.013247  40.716021 -73.999744        casual
# 2        5351.03  40.709267 -74.013247  40.716021 -73.999744        casual
# 3        8715.01  40.848282 -73.941343  40.872412 -73.912807        member
# 4        6602.03  40.772828 -73.966853  40.756405 -73.990026        casual
#
#          date  avgTemp  trips_per_day _merge
# 0  2022-01-01     11.6          20895   both
# 1  2022-01-01     11.6          20895   both
# 2  2022-01-01     11.6          20895   both
# 3  2022-01-01     11.6          20895   both
# 4  2022-01-01     11.6          20895   both

# %%
df.drop(columns = {'_merge'}, inplace = True)

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp', 'trips_per_day'],
#       dtype='object')

# %%
df.shape
# Out:
# (30689921, 16)

# %% [markdown]
# #### Setting a theme for the visualisation

# %%
sns.set_theme(style="dark")
custom_palette = sns.color_palette("GnBu_r")

# %% [markdown]
# #### Create a bar chart of the top 20 starting stations

# %%
df['value'] = 1

# %%
# Count the starting stations occurence

df_station = df.groupby('start_station_name')['value'].count().reset_index()

# %%
df_station

# %%
# Create a data for the top20 stations

top20 = df_station.nlargest(20, 'value')

# %%
top20
# Out:
#             start_station_name   value
# 1587           W 21 St & 6 Ave  131679
# 1718     West St & Chambers St  126290
# 495         Broadway & W 58 St  117797
# 286            6 Ave & W 33 St  109542
# 8              1 Ave & E 68 St  108412
# 461         Broadway & E 14 St  101115
# 485         Broadway & W 25 St  100784
# 1511   University Pl & E 14 St  100089
# 463         Broadway & E 21 St   97958
# 1603           W 31 St & 7 Ave   96157
# 788            E 33 St & 1 Ave   93955
# 590   Cleveland Pl & Spring St   92880
# 29            12 Ave & W 40 St   92550
# 287            6 Ave & W 34 St   92487
# 24            11 Ave & W 41 St   90159
# 1719      West St & Liberty St   89417
# 1105     Lafayette St & E 8 St   89318
# 562     Central Park S & 6 Ave   89062
# 328            8 Ave & W 33 St   88789
# 796         E 40 St & Park Ave   87752

# %%
#Create bar chart of the top20 station

sns.barplot(data = top20, x = 'value', y = 'start_station_name')
plt.title("The most popular starting stations")
plt.show()

# %% [markdown]
# ##### The colour palette chosen in the beginning of the step did not work for this plot, so I will be reassigning colour palette for this plot.

# %%
# Create bar chart of the top20 station with new palette

sns.barplot(data = top20, x = 'value', y = 'start_station_name',palette = "GnBu_r")
plt.title("The most popular starting stations")
plt.xlabel('Trip Count')
plt.ylabel('Starting Stations')
plt.show()
# Out:
# /var/folders/8k/dxgtncgd49g2ryx410bsc12r0000gn/T/ipykernel_7231/3415488100.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = top20, x = 'value', y = 'start_station_name',palette = "GnBu_r")

# %% [markdown]
# #### Re-create the dual axis line plot from previous exercise using seaborn

# %%
df_temp = df.set_index('date')

# %%
df_temp.head()
# Out:
#                      ride_id  rideable_type           started_at  \
# date
# 2022-01-01  F2147CAB2E003A12   classic_bike  2022-01-01 00:56:36
# 2022-01-01  27FF7FCE0F8A02DF   classic_bike  2022-01-01 15:42:26
# 2022-01-01  E413BC1D0B4C6031   classic_bike  2022-01-01 15:37:55
# 2022-01-01  1967ADD90811CE78  electric_bike  2022-01-01 17:35:23
# 2022-01-01  D199C729356BA836   classic_bike  2022-01-01 19:25:20
#
#                        ended_at        start_station_name start_station_id  \
# date
# 2022-01-01  2022-01-01 01:06:55  Cedar St & Evergreen Ave          4721.01
# 2022-01-01  2022-01-01 16:02:59  Albany St & Greenwich St          5145.02
# 2022-01-01  2022-01-01 16:03:05  Albany St & Greenwich St          5145.02
# 2022-01-01  2022-01-01 17:46:05   Cabrini Blvd & W 177 St           8358.1
# 2022-01-01  2022-01-01 19:41:53           5 Ave & E 72 St          7100.07
#
#                          end_station_name end_station_id  start_lat  \
# date
# 2022-01-01  Willoughby Ave & Tompkins Ave        4665.02  40.696710
# 2022-01-01          Bayard St & Baxter St        5351.03  40.709267
# 2022-01-01          Bayard St & Baxter St        5351.03  40.709267
# 2022-01-01            Broadway & W 220 St        8715.01  40.848282
# 2022-01-01                W 41 St & 8 Ave        6602.03  40.772828
#
#             start_lng    end_lat    end_lng member_casual  avgTemp  \
# date
# 2022-01-01 -73.928070  40.694254 -73.946269        member     11.6
# 2022-01-01 -74.013247  40.716021 -73.999744        casual     11.6
# 2022-01-01 -74.013247  40.716021 -73.999744        casual     11.6
# 2022-01-01 -73.941343  40.872412 -73.912807        member     11.6
# 2022-01-01 -73.966853  40.756405 -73.990026        casual     11.6
#
#             trips_per_day  trip_duration  value
# date
# 2022-01-01          20895      10.316667      1
# 2022-01-01          20895      20.550000      1
# 2022-01-01          20895      25.166667      1
# 2022-01-01          20895      10.700000      1
# 2022-01-01          20895      16.550000      1

# %%
df_temp = df_temp.sort_values(by='date')

# %%
# Create dual axis line chart for bike trip counts and average temperature

fig,ax = plt.subplots(figsize=(12, 6))
sns.lineplot(data = df_temp['trips_per_day'], color = "navy")
ax.set_xlabel("Year 2022", fontsize = 12) # set x-axis label
ax.set_ylabel("Bike trips count",color = "navy", fontsize = 12) # set y-axis label

ax2 = ax.twinx()
sns.lineplot(data = df_temp['avgTemp'], color="mediumaquamarine", ax=ax2)
ax2.set_ylabel("Average temperatures", color = "mediumaquamarine",fontsize=12)
plt.title('Bike Trips count and avg Temperatures in 2022', fontsize = 14)
plt.show()

# %%
df.isnull().sum()
# Out:
# ride_id                   0
# rideable_type             0
# started_at                0
# ended_at                  0
# start_station_name       50
# start_station_id         50
# end_station_name      71773
# end_station_id        71773
# start_lat                 0
# start_lng                 0
# end_lat               37516
# end_lng               37516
# member_casual             0
# date                      0
# avgTemp                   0
# trips_per_day             0
# value                     0
# dtype: int64

# %% [markdown]
# #### Create box plot of one of the categorical variables in the dataset

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# date                   object
# avgTemp               float64
# trips_per_day           int64
# value                   int64
# dtype: object

# %%
# Convert 'started_at' and 'ended_at' to datetime

df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])

# %%
# Calculate the trip duration in minutes

df['trip_duration'] = (df['ended_at'] - df['started_at']).dt.total_seconds() / 60

# %%
# Create a box plot

plt.figure(figsize=(8, 16))
sns.boxplot(x='member_casual', y='trip_duration', data=df)
plt.title('Trip Duration by Member Type')
plt.xlabel('Member Type')
plt.ylabel('Trip Duration (mins)')
plt.show()

# %%
df['trip_duration'].describe()
# Out:
# count    3.068992e+07
# mean     1.725109e+01
# std      8.916414e+01
# min     -1.130117e+03
# 25%      5.466667e+00
# 50%      9.866667e+00
# 75%      1.766667e+01
# max      5.798598e+04
# Name: trip_duration, dtype: float64

# %%
# Box plot with limitation on Y (to zoom in the results as the casual member have a quite distant outlier)

plt.figure(figsize=(8, 12))
sns.boxplot(x='member_casual', y='trip_duration', data=df, palette=custom_palette)
plt.title('Trip Duration by Member Type')
plt.xlabel('Member Type')
plt.ylabel('Trip Duration (mins)')
plt.ylim(0, 100)
plt.show()
# Out:
# /var/folders/8k/dxgtncgd49g2ryx410bsc12r0000gn/T/ipykernel_7231/2121967731.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='member_casual', y='trip_duration', data=df, palette=custom_palette)
# /var/folders/8k/dxgtncgd49g2ryx410bsc12r0000gn/T/ipykernel_7231/2121967731.py:4: UserWarning: The palette list has more values (6) than needed (2), which may not be intended.
#   sns.boxplot(x='member_casual', y='trip_duration', data=df, palette=custom_palette)

# %%
df['member_casual'].value_counts()
# Out:
# member_casual
# member    23995071
# casual     6694850
# Name: count, dtype: int64

# %% [markdown]
# ##### Based on the box plots above we can see that there is quite a difference in the trip duration distribution between the 2 different types of customers that we have. Casual based customer seems to have a wider range of outliers, meaning their trips are more varied to short and longer time period. While, the member customers seems to have more regular period. In general, casual customers are using the bike longer than most of the Citi Bike membership customer, who generally uses the bike in less than 20 minutes.

# %% [markdown]
# #### Create a FacetGrid

# %%
# Create the FacetGrid with the  data
grid = sns.FacetGrid(df, col="member_casual", col_wrap=3, height=4, aspect=1.5)
grid.map_dataframe(sns.countplot, x="rideable_type", order=df['rideable_type'].value_counts().index)

grid.set_axis_labels('Rideable Type', 'Count')
grid.set_titles(col_template="{col_name}")

plt.show()

# %% [markdown]
# ##### Based on the FacetGrid above, we can see both member and casual customer of Citi Bike prefer to use the classic bike. Interestingly, some of the casual customers actually use docked bike more than the members.

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'date', 'avgTemp', 'trips_per_day', 'trip_duration'],
#       dtype='object')

# %%
df.to_csv('nycbike_data2.csv')
